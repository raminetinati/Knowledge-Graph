# %% [markdown]
# # Intelligent Knowledge Graph - Data Exploration
#
# Add some content

# %% [markdown]
# ### Imports

# %%
import json
import pandas as pd
import os
import jsonlines
import networkx
import dgl
import cufflinks
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
from sklearn.preprocessing import OneHotEncoder
import copy
from gensim.models import Word2Vec 
import itertools
import umap
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %% [markdown]
# ### Configs

# %%
configs = {}
env_vars = {}

# %% [markdown]
# ### Load Data

# %%
def load_data(path, filename):
    
    filepath = os.path.join(path, filename) 
    print('Loading File from Path {}'.format(filepath))
    
    data = []
    with open(filepath, "r") as f:
        for l in f:
            data = l.replace('}{','}\n{')
    
    df = pd.read_json(data, lines=True)
    return df
    
df = load_data('../data','cleaned_related_skills.json')
# Out:
# Loading File from Path ../data/cleaned_related_skills.json

# %%
def data_summary(df, index_col):
    
    print('Dataframe shape {}'.format(df.shape))
    print('Dataframe Name Unique Rows {}'.format(df.groupby(index_col)[index_col].count().shape[0]))
    
    
data_summary(df, 'name')
# Out:
# Dataframe shape (28934, 11)
# Dataframe Name Unique Rows 28934

# %% [markdown]
# ### Insight 1:
#
# Lets see the frequency of skills across the entire population. To do this we're goint to bin the skills into a new dataframe and then perform the counts

# %%
def skills_frequency(df, index_col):
    
    skills =[]
    cols = list(df.columns)
    cols.remove(index_col) 
    
    for idx,row in df.iterrows():
        
        for col in cols:
#             print(col)
            skills.append(row[col])
                
    df_dic = {'skills':skills}
    
    df_skills = pd.DataFrame(df_dic)
    
    return df_skills
    
    
df_skills = skills_frequency(df, 'name')

# %%
def plot_skills(df):
    
    col = 'skills'
        
    print('Total Non-unique Skills {}'.format(df.shape[0]))

    print('Unique Skills {}'.format(df.groupby(col).count().shape[0]))
    
    print('Pandas Describe:\n', df.describe())
    
    
    df.groupby('skills')['skills'].count().sort_values(ascending=False).head(30).plot(kind='bar', figsize=(20,15))

plot_skills(df_skills)
# Out:
# Total Non-unique Skills 289340
# Unique Skills 28076
# Pandas Describe:
#          skills
# count   289069
# unique   28076
# top          c
# freq       588

# %% [markdown]
# ### Insight 2: Association Rule Mining

# %%
def transform_df_ohe(df, df_skills, index_col):
    
#     
    cols = list(df.columns)
    cols.remove(index_col)    

    datas = []
    for idx,row in df.iterrows():
        
        data = []
        for col in cols:
            data.append(str(row[col]))
        datas.append(data)
        
    te = TransactionEncoder()
    te_ary = te.fit(datas).transform(datas)

    df_ohe = pd.DataFrame(te_ary, columns=te.columns_)
    
    return df_ohe

df_ohe = transform_df_ohe(df, df_skills,'name')

# %%
def calc_aprior(df, min_support= 0.6, max_len=None):
    
    freq_items = apriori(df, min_support=min_support, max_len=max_len, use_colnames=True, verbose=1)
    return freq_items

freq_items = calc_aprior(df_ohe, min_support= 0.006, max_len=None)
# Out:
# Processing 51 combinations | Sampling itemset size 3

# %%
freq_items['length'] = freq_items['itemsets'].apply(lambda x: len(x))
freq_items
# Out:
#      support                            itemsets  length
# 0   0.011751                  (active directory)       1
# 1   0.010161                           (autocad)       1
# 2   0.020322                                 (c)       1
# 3   0.009608                               (css)       1
# 4   0.006048                 (gestion de projet)       1
# 5   0.006981                    (graphic design)       1
# 6   0.006152                         (hibernate)       1
# 7   0.016659                              (java)       1
# 8   0.019320                        (javascript)       1
# 9   0.010438                            (jquery)       1
# 10  0.008364                             (linux)       1
# 11  0.008468                            (matlab)       1
# 12  0.006359                  (microsoft office)       1
# 13  0.007396              (microsoft sql server)       1
# 14  0.008295                 (molecular biology)       1
# 15  0.006290                             (music)       1
# 16  0.010368                             (mysql)       1
# 17  0.007811                         (photoshop)       1
# 18  0.007431                               (php)       1
# 19  0.007189                               (sql)       1
# 20  0.006152                (telecommunications)       1
# 21  0.012096                    (windows server)       1
# 22  0.009850  (windows server, active directory)       2
# 23  0.007707                   (javascript, css)       2
# 24  0.007534                       (jquery, css)       2
# 25  0.007051                  (javascript, java)       2
# 26  0.009712                (javascript, jquery)       2
# 27  0.007845                 (javascript, mysql)       2
# 28  0.006290                   (php, javascript)       2
# 29  0.007085           (css, javascript, jquery)       3

# %%
def association_rule_gen(freq_items):
    
    rules = association_rules(freq_items, metric="lift", min_threshold=0.0001)
    
    display(rules.head(20))
    
association_rule_gen(freq_items)
# Out:
#              antecedents           consequents  antecedent support  \
# 0       (windows server)    (active directory)            0.012096
# 1     (active directory)      (windows server)            0.011751
# 2           (javascript)                 (css)            0.019320
# 3                  (css)          (javascript)            0.009608
# 4               (jquery)                 (css)            0.010438
# 5                  (css)              (jquery)            0.009608
# 6           (javascript)                (java)            0.019320
# 7                 (java)          (javascript)            0.016659
# 8           (javascript)              (jquery)            0.019320
# 9               (jquery)          (javascript)            0.010438
# 10          (javascript)               (mysql)            0.019320
# 11               (mysql)          (javascript)            0.010368
# 12                 (php)          (javascript)            0.007431
# 13          (javascript)                 (php)            0.019320
# 14     (javascript, css)              (jquery)            0.007707
# 15         (jquery, css)          (javascript)            0.007534
# 16  (javascript, jquery)                 (css)            0.009712
# 17                 (css)  (javascript, jquery)            0.009608
# 18          (javascript)         (jquery, css)            0.019320
# 19              (jquery)     (javascript, css)            0.010438
#
#     consequent support   support  confidence       lift  leverage  conviction
# 0             0.011751  0.009850    0.814286  69.295714  0.009708    5.321341
# 1             0.012096  0.009850    0.838235  69.295714  0.009708    6.107040
# 2             0.009608  0.007707    0.398927  41.519942  0.007522    1.647706
# 3             0.019320  0.007707    0.802158  41.519942  0.007522    4.956892
# 4             0.009608  0.007534    0.721854  75.129973  0.007434    3.560695
# 5             0.010438  0.007534    0.784173  75.129973  0.007434    4.584973
# 6             0.016659  0.007051    0.364937  21.906843  0.006729    1.548416
# 7             0.019320  0.007051    0.423237  21.906843  0.006729    1.700316
# 8             0.010438  0.009712    0.502683  48.161061  0.009510    1.989804
# 9             0.019320  0.009712    0.930464  48.161061  0.009510   14.103115
# 10            0.010368  0.007845    0.406082  39.165283  0.007645    1.666277
# 11            0.019320  0.007845    0.756667  39.165283  0.007645    4.030192
# 12            0.019320  0.006290    0.846512  43.815684  0.006147    6.389280
# 13            0.007431  0.006290    0.325581  43.815684  0.006147    1.471741
# 14            0.010438  0.007085    0.919283  88.074570  0.007005   12.259579
# 15            0.019320  0.007085    0.940367  48.673664  0.006940   16.445252
# 16            0.009608  0.007085    0.729537  75.929619  0.006992    3.661844
# 17            0.009712  0.007085    0.737410  75.929619  0.006992    3.771235
# 18            0.007534  0.007085    0.366726  48.673664  0.006940    1.567199
# 19            0.007707  0.007085    0.678808  88.074570  0.007005    3.089406

# %% [markdown]
# ### Insight 3: Word2Vec

# %%
#Lets create all the combinations from a given list...
def transform_into_combinations(df, df_skills, index_col):
    
#     
    cols = list(df.columns)
    cols.remove(index_col)    

    datas = []
    for idx,row in df.iterrows():
        data = []
        for col in cols:
            data.append(str(row[col]))
        datas.append(data)
        
    #now for each row, generate the combinations
    train = []
    for row in datas:
        all_combins = []
#         for i in range(2,3):
#             print(i)
        combins = list(itertools.combinations(row, 2))
        for entry in combins:
            all_combins.append(list(entry))
#         print(all_combins)
        train.append(list(itertools.chain(*all_combins)))
    return train

    


w2c_train = transform_into_combinations(df, df_skills, 'name')

# %%
def build_w2v_model(train_data):
    
    model = Word2Vec(window = 10, 
                     sg = 1, hs = 0,
                     negative = 10, # for negative sampling
                     alpha=0.03, min_alpha=0.0007,
                     seed = 10,
                     min_count=50)
    
    model.build_vocab(train_data, progress_per=200)

    
    model.train(train_data, total_examples = model.corpus_count, 
            epochs=10, report_delay=1)
    
    return model

# %%
w2v_model = build_w2v_model(w2c_train)

# %%
w2v_model.init_sims(replace=True)

# %%
print(w2v_model)
# Out:
# Word2Vec(vocab=28077, size=100, alpha=0.03)

# %%
def visualize_model(model):
    
    X = w2v_model[w2v_model.wv.vocab]
    X.shape

    cluster_embedding = umap.UMAP(n_neighbors=30, min_dist=0.0,
                                  n_components=2, random_state=42).fit_transform(X)

    plt.figure(figsize=(10,9))
    plt.scatter(cluster_embedding[:, 0], cluster_embedding[:, 1], s=3, cmap='Spectral')
    
    
visualize_model(w2v_model)
# Out:
# /Users/ramine.tinati/anaconda3/envs/gpu-tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
def evaluate_model_results(model):
    
    labels = []
    tokens = []

    for word in model.wv.vocab:
        tokens.append(model[word])
        labels.append(word)
    
    
    #cheapest way to find maximum number of vectors to generate our TSNE representations

    tsne = TSNE(perplexity=4, n_components=2, init='pca', n_iter=10000, verbose=1)
    
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(16, 16)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()    
    print('Total Tokens {}'.format(len(labels)))
    

    return two_d_embeddings, labels

two_d_embeddings, labels = evaluate_model_results(w2v_model)

# %%
def w2v_calc_similarity(vector)
